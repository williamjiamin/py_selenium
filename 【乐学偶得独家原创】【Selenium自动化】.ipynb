# %% [markdown]
# 乐学偶得版权所有  公众号：乐学Fintech  主讲人：William LX_LAB教研团队提供技术支持 正版视频： 网易云课堂：乐学偶得

# %% [markdown]
# 1.通过编程手段直接通过给服务器发请求，通过对返回信息进行解析，最终实现数据的获取（底层）
# 2.通过控制浏览器进行给服务器发请求，通过获取浏览器中的信息，最终实现数据的获取（不太涉及底层）

# %% [markdown]
# ![8020rule.png](attachment:8020rule.png)
